# %%
from schic_class import scHiC  

example = scHiC()

example.load_cells("sc_hic_maps")

example.load_metadata("scHiC_subset_metadata.csv")
# Out:
# 2025-05-01 11:49:01,085 - INFO - Successfully loaded 360 .cool files.
# 2025-05-01 11:49:01,092 - INFO - Metadata loaded from scHiC_subset_metadata.csv
# 2025-05-01 11:49:01,094 - INFO - Metadata filtered to 360 cells.

# %%
# Get statistics
example.describe()
# Out:
#                                              Cell Name      Matrix Shape  \
# 0    GSM6799885_HBA_211130_H1930001_CX51_MTG_3C_1_P...  (308839, 308839)
# 1    GSM6803242_HBA_211130_H1930002_CX52_MTG_3C_1_P...  (308839, 308839)
# 2    GSM6798794_HBA_211130_H1930001_CX51_MTG_3C_1_P...  (308839, 308839)
# 3    GSM6798923_HBA_211130_H1930001_CX51_MTG_3C_1_P...  (308839, 308839)
# 4    GSM6804265_HBA_211130_H1930002_CX52_MTG_3C_1_P...  (308839, 308839)
# ..                                                 ...               ...
# 495  GSM6799406_HBA_211130_H1930001_CX51_MTG_3C_1_P...  (308839, 308839)
# 496  GSM6799276_HBA_211130_H1930001_CX51_MTG_3C_1_P...  (308839, 308839)
# 497  GSM6798717_HBA_211130_H1930001_CX51_MTG_3C_1_P...  (308839, 308839)
# 498  GSM6802919_HBA_211130_H1930002_CX52_MTG_3C_1_P...  (308839, 308839)
# 499  GSM6802044_HBA_211130_H1930002_CX52_MTG_3C_1_P...  (308839, 308839)
#
#      Total Contacts  Non-zero Contacts  Sparsity (%)  Mean Contact Value  \
# ...

# %%
example.describe_all()
# Out:
# Aggregated Statistics for All Cells:
# ...
# Total Cells                   : 500
# Average Matrix Shape          : (308839, 308839)
# Total Contacts (All Cells)    : 206124597
# Average Non-zero Contacts     : 336972.396
# Average Sparsity (%)          : 99.99964671105262
# Average Mean Contact Value    : 1.2211714827843065
# Median Mean Contact Value     : 1.2121439432443162
# Min Mean Contact Value        : 1.138322303179607
# Max Mean Contact Value        : 1.411923790913532
# Average Std Contact Value     : 0.550380323371789
# ...
# {'Total Cells': 500,
#  'Average Matrix Shape': (308839, 308839),
#  'Total Contacts (All Cells)': np.int64(206124597),
#  'Average Non-zero Contacts': np.float64(336972.396),
#  'Average Sparsity (%)': np.float64(99.99964671105262),
#  'Average Mean Contact Value': np.float64(1.2211714827843065),
#  'Median Mean Contact Value': np.float64(1.2121439432443162),
#  'Min Mean Contact Value': np.float64(1.138322303179607),
# ...

# %%
from schic_vis import (
    plot_hic_maps,
    plot_contact_frequency_distribution,
    plot_sparsity_distribution,
    plot_mean_contact_boxplot,
    plot_non_zero_violin,
    plot_cumulative_contact_distribution,
    plot_correlation_heatmap
)

# Example usage:
plot_hic_maps(
    schic_obj=example,
    region="chr1:1000000-10000000",
    group_col="MajorType",
    cmap="Reds",
    resolution=1000000  # Show ticks every 1Mb
)
# Out:
# 2025-05-01 12:27:41,920 - INFO - Region chr1:1000000-10000000: Found 900 bins
# 2025-05-01 12:27:42,907 - INFO - Processing group: L4-IT
# 2025-05-01 12:27:46,739 - INFO - Processing group: L5-IT
# 2025-05-01 12:27:49,735 - INFO - Processing group: L6-IT
# 2025-05-01 12:27:52,258 - INFO - Processing group: L6-CT

# %%
plot_sparsity_distribution(example)

# %%
plot_mean_contact_boxplot(example, group_column="MajorType")
# Out:
# /home/schic/schic_vis.py:196: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=group_column, y="Mean Contact Value", data=schic.metadata, palette=palette)

# %%
plot_non_zero_violin(example, group_column="MajorType")
# Out:
# /home/schic/schic_vis.py:228: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=group_column, y="Non-zero Contacts", data=schic.metadata, palette=palette)
